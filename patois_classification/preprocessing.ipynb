# %%
import pandas as pd

# Load your dataset
data = pd.read_csv("training.csv")

# Count the number of instances for each emotion label
label_counts = data.drop('text', axis=1).sum()


# Print label counts
print("Label Counts:")
print(label_counts)

# Plot the distribution
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
label_counts.plot(kind='bar')
plt.title('Distribution of Emotion Labels')
plt.xlabel('Emotion Labels')
plt.ylabel('Number of Instances')
plt.xticks(rotation=45)
plt.show()
# Out:
# Label Counts:
# Joy                97.0
# Anger              92.0
# Sadness            72.0
# Surprise           81.0
# Fear               39.0
# Disgust            64.0
# Love               75.0
# Confusion          29.0
# Disappointment     29.0
# Neutral           164.0
# Frustration        21.0
# Admiration         25.0
# Excitement          0.0
# Pride               0.0
# Desire              0.0
# Curiousity          0.0
# Optimism            0.0
# Disapproval         0.0
# dtype: float64
